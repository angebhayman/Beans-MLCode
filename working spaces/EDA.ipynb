# %%
# Importing Data
import pandas as pd 
df = pd.read_csv("final_df.csv")
df = pd.DataFrame(df)

# %%
df = df.drop_duplicates()

# If you want to reset the index after removing duplicates
df.reset_index(drop=True, inplace=True)

# Optionally, you can check the shape of the DataFrame before and after removing duplicates
print("DataFrame shape before removing duplicates:", df.shape)
# Out:
# DataFrame shape before removing duplicates: (35464, 22)

# %%
print(df.head())
# Out:
#   DBN_x  average_rating  year                   School Name    Q1    Q2    Q3  \
# 0  K001        6.833333  2017           P.S. 001 The Bergen  0.94  0.94  0.98
# 1  K001        6.833333  2021           P.S. 001 The Bergen  0.90  0.91  0.96
# 2  K001        6.833333  2022           P.S. 001 The Bergen  0.95  0.96  0.98
# 3  K001        6.833333  2022           P.S. 001 The Bergen  0.97  0.96  0.99
# 4  K002        8.000000  2017  Parkside Preparatory Academy  0.87  0.90  0.97
#
#      Q4    Q5    Q6  ...    Q9   Q10   Q11   Q12   Q13   Q14   Q15   Q16  \
# 0  0.95  0.97  0.97  ...  0.98  0.96  0.96  0.96  0.96  0.98  0.94  0.94
# 1  0.91  0.96  0.97  ...  0.94  0.96  0.93  0.96  0.95  0.97  0.06  0.08
# 2  0.95  0.99  0.99  ...  0.97  0.97  0.96  0.97  0.97  0.97  0.99  0.98
# 3  0.97  0.99  0.99  ...  0.98  0.98  0.98  0.99  0.99  0.98  0.98  0.97
# 4  0.92  0.94  0.96  ...  0.92  0.92  0.89  0.97  0.95  0.91  0.94  0.95
#
#     Q17   Q18
# 0  0.96  0.89
# 1  0.04  0.72
# 2  0.98  0.22
# 3  0.97  0.06
# 4  0.94  0.88
#
# [5 rows x 22 columns]

# %%
# General Look
print(df.shape)
print(df.head())
print(df.tail())
print(df.describe())
print(df.info())
print(df.dtypes)
# Out:
# (35464, 22)
#   DBN_x  average_rating  year                   School Name    Q1    Q2    Q3  \
# 0  K001        6.833333  2017           P.S. 001 The Bergen  0.94  0.94  0.98
# 1  K001        6.833333  2021           P.S. 001 The Bergen  0.90  0.91  0.96
# 2  K001        6.833333  2022           P.S. 001 The Bergen  0.95  0.96  0.98
# 3  K001        6.833333  2022           P.S. 001 The Bergen  0.97  0.96  0.99
# 4  K002        8.000000  2017  Parkside Preparatory Academy  0.87  0.90  0.97
#
#      Q4    Q5    Q6  ...    Q9   Q10   Q11   Q12   Q13   Q14   Q15   Q16  \
# 0  0.95  0.97  0.97  ...  0.98  0.96  0.96  0.96  0.96  0.98  0.94  0.94
# 1  0.91  0.96  0.97  ...  0.94  0.96  0.93  0.96  0.95  0.97  0.06  0.08
# 2  0.95  0.99  0.99  ...  0.97  0.97  0.96  0.97  0.97  0.97  0.99  0.98
# 3  0.97  0.99  0.99  ...  0.98  0.98  0.98  0.99  0.99  0.98  0.98  0.97
# 4  0.92  0.94  0.96  ...  0.92  0.92  0.89  0.97  0.95  0.91  0.94  0.95
#
#     Q17   Q18
# 0  0.96  0.89
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.940000      0.880000      0.880000      0.900000      0.160000
# 50%        0.970000      0.950000      0.940000      0.960000      0.440000
# 75%        0.980000      0.970000      0.970000      0.980000      0.870000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35464 entries, 0 to 35463
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DBN_x           35464 non-null  object
#  1   average_rating  34570 non-null  float64
#  2   year            35464 non-null  int64
#  3   School Name     35464 non-null  object
#  4   Q1              34824 non-null  float64
#  5   Q2              34824 non-null  float64
#  6   Q3              34812 non-null  float64
#  7   Q4              34824 non-null  float64
#  8   Q5              34812 non-null  float64
#  9   Q6              34806 non-null  float64
#  10  Q7              34812 non-null  float64
#  11  Q8              34794 non-null  float64
#  12  Q9              34788 non-null  float64
#  13  Q10             34752 non-null  float64
#  14  Q11             34782 non-null  float64
#  15  Q12             34776 non-null  float64
#  16  Q13             34776 non-null  float64
#  17  Q14             34748 non-null  float64
#  18  Q15             34794 non-null  float64
#  19  Q16             34812 non-null  float64
#  20  Q17             34800 non-null  float64
#  21  Q18             34818 non-null  float64
# dtypes: float64(19), int64(1), object(2)
# memory usage: 6.0+ MB
# None
# DBN_x              object
# average_rating    float64
# year                int64
# School Name        object
# Q1                float64
# Q2                float64
# Q3                float64
# Q4                float64
# Q5                float64
# Q6                float64
# Q7                float64
# Q8                float64
# Q9                float64
# Q10               float64
# Q11               float64
# Q12               float64
# Q13               float64
# Q14               float64
# Q15               float64
# Q16               float64
# Q17               float64
# Q18               float64
# dtype: object

# %%
# Converting Percentages to Decimals
columns_to_convert = [f'Q{i}' for i in range(1, 19)] 
df[columns_to_convert] = df[columns_to_convert].apply(lambda x: x.str.rstrip('%').astype(float) / 100)
print(df)
# Out:
#       DBN_x  average_rating  year                   School Name    Q1    Q2  \
# 0      K001        6.833333  2017           P.S. 001 The Bergen  0.94  0.94
# 1      K001        6.833333  2021           P.S. 001 The Bergen  0.90  0.91
# 2      K001        6.833333  2022           P.S. 001 The Bergen  0.95  0.96
# 3      K001        6.833333  2022           P.S. 001 The Bergen  0.97  0.96
# 4      K002        8.000000  2017  Parkside Preparatory Academy  0.87  0.90
# ...     ...             ...   ...                           ...   ...   ...
# 37117  X811        7.247059  2018                     P.S. X811  0.94  0.94
# 37118  X811        7.247059  2019                     P.S. X811  0.89  0.95
# 37119  X811        7.247059  2021                     P.S. X811  0.90  0.98
# 37120  X811        7.247059  2022                     P.S. X811  0.89  0.94
# 37121  X811        7.247059  2022                     P.S. X811  0.87  0.91
#
#          Q3    Q4    Q5    Q6  ...    Q9   Q10   Q11   Q12   Q13   Q14   Q15  \
# 0      0.98  0.95  0.97  0.97  ...  0.98  0.96  0.96  0.96  0.96  0.98  0.94
# 1      0.96  0.91  0.96  0.97  ...  0.94  0.96  0.93  0.96  0.95  0.97  0.06
# 2      0.98  0.95  0.99  0.99  ...  0.97  0.97  0.96  0.97  0.97  0.97  0.99
# 3      0.99  0.97  0.99  0.99  ...  0.98  0.98  0.98  0.99  0.99  0.98  0.98
# 4      0.97  0.92  0.94  0.96  ...  0.92  0.92  0.89  0.97  0.95  0.91  0.94
# ...     ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 37117  0.98  0.97  0.97  0.95  ...  0.97  0.94  0.95  0.97  0.97  0.97  0.97
# 37118  0.97  0.94  0.95  0.96  ...  0.93  0.94  0.95  0.95  0.93  0.95  0.95
# 37119  0.98  0.95  0.98  0.93  ...  0.95  0.91  0.92  0.93  0.93  0.94  0.02
# 37120  0.97  0.90  0.98  0.94  ...  0.95  0.93  0.95  0.95  0.97  0.96  0.96
# 37121  0.97  0.92  0.96  0.94  ...  0.95  0.92  0.94  0.96  0.95  0.99  0.93
#
#         Q16   Q17   Q18
# 0      0.94  0.96  0.89
# 1      0.08  0.04  0.72
# 2      0.98  0.98  0.22
# 3      0.97  0.97  0.06
# 4      0.95  0.94  0.88
# ...     ...   ...   ...
# 37117  0.98  0.98  0.93
# 37118  0.95  0.96  0.86
# 37119  0.03  0.00  0.73
# 37120  0.94  0.95  0.21
# 37121  0.93  0.96  0.12
#
# [37122 rows x 22 columns]

# %%
# Look after Conversion
print(df.shape)
print(df.head())
print(df.tail())
print(df.describe())
print(df.info())
print(df.dtypes)
# Out:
# (37122, 22)
#   DBN_x  average_rating  year                   School Name    Q1    Q2    Q3  \
# 0  K001        6.833333  2017           P.S. 001 The Bergen  0.94  0.94  0.98
# 1  K001        6.833333  2021           P.S. 001 The Bergen  0.90  0.91  0.96
# 2  K001        6.833333  2022           P.S. 001 The Bergen  0.95  0.96  0.98
# 3  K001        6.833333  2022           P.S. 001 The Bergen  0.97  0.96  0.99
# 4  K002        8.000000  2017  Parkside Preparatory Academy  0.87  0.90  0.97
#
#      Q4    Q5    Q6  ...    Q9   Q10   Q11   Q12   Q13   Q14   Q15   Q16  \
# 0  0.95  0.97  0.97  ...  0.98  0.96  0.96  0.96  0.96  0.98  0.94  0.94
# 1  0.91  0.96  0.97  ...  0.94  0.96  0.93  0.96  0.95  0.97  0.06  0.08
# 2  0.95  0.99  0.99  ...  0.97  0.97  0.96  0.97  0.97  0.97  0.99  0.98
# 3  0.97  0.99  0.99  ...  0.98  0.98  0.98  0.99  0.99  0.98  0.98  0.97
# 4  0.92  0.94  0.96  ...  0.92  0.92  0.89  0.97  0.95  0.91  0.94  0.95
#
#     Q17   Q18
# 0  0.96  0.89
# 1  0.04  0.72
# 2  0.98  0.22
# 3  0.97  0.06
# 4  0.94  0.88
#
# [5 rows x 22 columns]
#       DBN_x  average_rating  year School Name    Q1    Q2    Q3    Q4    Q5  \
# 37117  X811        7.247059  2018   P.S. X811  0.94  0.94  0.98  0.97  0.97
# 37118  X811        7.247059  2019   P.S. X811  0.89  0.95  0.97  0.94  0.95
# 37119  X811        7.247059  2021   P.S. X811  0.90  0.98  0.98  0.95  0.98
columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DBN_x           37122 non-null  object
#  1   average_rating  36155 non-null  float64
#  2   year            37122 non-null  int64
#  3   School Name     37122 non-null  object
#  4   Q1              36312 non-null  float64
#  5   Q2              36312 non-null  float64
#  6   Q3              36300 non-null  float64
#  7   Q4              36312 non-null  float64
#  8   Q5              36300 non-null  float64
#  9   Q6              36294 non-null  float64
#  10  Q7              36300 non-null  float64
#  11  Q8              36282 non-null  float64
#  12  Q9              36276 non-null  float64
#  13  Q10             36240 non-null  float64
#  14  Q11             36270 non-null  float64
#  15  Q12             36264 non-null  float64
#  16  Q13             36264 non-null  float64
#  17  Q14             36234 non-null  float64
#  18  Q15             36282 non-null  float64
#  19  Q16             36300 non-null  float64
#  20  Q17             36288 non-null  float64
#  21  Q18             36306 non-null  float64
# dtypes: float64(19), int64(1), object(2)
# memory usage: 6.2+ MB
# None
# DBN_x              object
# average_rating    float64
# year                int64
# School Name        object
# Q1                float64
# Q2                float64
# Q3                float64
# Q4                float64
# Q5                float64
# Q6                float64
# Q7                float64
# Q8                float64
# Q9                float64
# Q10               float64
# Q11               float64
# Q12               float64
# Q13               float64
# Q14               float64
# Q15               float64
# Q16               float64
# Q17               float64
# Q18               float64
# dtype: object

# %%
# Checking for Outliers
import seaborn as sns
import matplotlib.pyplot as plt

exclude_columns = ['School Name'] 
columns_to_plot = df.drop(columns=exclude_columns).columns
plt.figure(figsize=(15, 10))
for i, col in enumerate(columns_to_plot, 1):
    plt.subplot((len(columns_to_plot) // 3) + 1, 3, i) 
    sns.boxplot(data=df, y=col)
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
# Looking at the Distribution
columns_to_plot = [f'Q{i}' for i in range(1, 19)] + ['average_rating']

plt.figure(figsize=(15, 10))

num_columns = len(columns_to_plot)
num_rows = (num_columns // 3) + (num_columns % 3 > 0)  

for i, col in enumerate(columns_to_plot, 1):
    plt.subplot(num_rows, 3, i) 
    sns.histplot(data=df, x=col, bins=30, kde=True) 
    plt.title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %%
columns_to_analyze = [f'Q{i}' for i in range(1, 19)] + ['average_rating']  # Q1 to Q18 and average_rating

correlation_matrix = df[columns_to_analyze].corr()

plt.figure(figsize=(12, 8))

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

plt.title('Correlation Matrix of Q1 to Q18 and Average Rating', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Looking at Average Pavement Ratings
sns.histplot(df['average_rating'], bins=30, kde=True)
plt.title('Distribution of Pavement Rating')
plt.show()

# %%
# Checking for Nulls
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# DBN_x               0
# average_rating    967
# year                0
# School Name         0
# Q1                810
# Q2                810
# Q3                822
# Q4                810
# Q5                822
# Q6                828
# Q7                822
# Q8                840
# Q9                846
# Q10               882
# Q11               852
# Q12               858
# Q13               858
# Q14               888
# Q15               840
# Q16               822
# Q17               834
# Q18               816
# dtype: int64
